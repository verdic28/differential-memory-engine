# %% [markdown]
# <a href="https://colab.research.google.com/github/verdic28/differential-memory-engine/blob/main/differential_memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone your repository directly into the Colab environment
# !git clone https://github.com/verdic28/differential-memory-engine.git

# 2. Change the working directory to your repo folder
# %cd differential-memory-engine

# 3. Install the specific production dependencies
# !pip install numpy scikit-learn

# 4. Execute the professional demo script
# !python demo.py
# Out:
# Cloning into 'differential-memory-engine'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 6.97 KiB | 6.97 MiB/s, done.
# /content/differential-memory-engine
# ...
# --- [INITIALIZING] Differential Memory Engine v2.0 ---
#
# [TURN 1] Committing core logic...
# Status: {"status": "COMMITTED_DIFFERENTIAL", "novelty": 1.0}
#
# [TURN 2] Attempting to commit redundant data...
# Status: COMMITTED_DIFFERENTIAL | Novelty Score: 1.0169
# Result: Engine correctly identified and rejected redundant information.
#
# [TURN 3] Committing new operational constraints...
# Status: {"status": "COMMITTED_DIFFERENTIAL", "novelty": 0.974678531274238}
#
# --- [QUERY] Executing Latent State Recall ---
# Query: What are my current trading limits and profit goals?
# ...
